# %%
#import for analysis data
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
#get files
files = [file for file in os.listdir("home-credit-default-risk/")]
print(files)
# Out:
# ['application_test.csv', 'application_train.csv', 'bureau.csv', 'bureau_balance.csv', 'credit_card_balance.csv', 'Dataset+Description+-+Task+4.pdf', 'HomeCredit_columns_description.csv', 'installments_payments.csv', 'Pedoman+Pembuatan+PPT+-+Task+4+-+HCI.pdf', 'POS_CASH_balance.csv', 'previous_application.csv', 'sample_submission.csv']

# %%
application_test = pd.read_csv("home-credit-default-risk/application_test.csv")
application_train = pd.read_csv("home-credit-default-risk/application_train.csv")
bureau_balance = pd.read_csv("home-credit-default-risk/bureau_balance.csv")
bureau = pd.read_csv("home-credit-default-risk/bureau.csv")
credit_card_balance = pd.read_csv("home-credit-default-risk/credit_card_balance.csv")
installments_payments = pd.read_csv("home-credit-default-risk/installments_payments.csv")
posh_cash_balance = pd.read_csv("home-credit-default-risk/POS_CASH_balance.csv")
previous_application = pd.read_csv("home-credit-default-risk/previous_application.csv")
sample_submission = pd.read_csv("home-credit-default-risk/sample_submission.csv")

# %% [markdown]
# Check Sample Data

# %%
application_test.sample(5)
# Out:
#        SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 18250      232547         Cash loans           M            N               Y
# 23797      273109         Cash loans           F            Y               Y
# 39080      388174         Cash loans           M            Y               N
# 8456       161927         Cash loans           F            N               Y
# 48723      456058         Cash loans           F            N               N
#
#        CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 18250             0          225000.0    167076.0      12928.5
# 23797             0          450000.0   2013840.0      62640.0
# 39080             2          180000.0    810000.0      34317.0
# 8456              0          279000.0    853200.0      27652.5
# 48723             1           67500.0    315000.0      16213.5
#
#        AMT_GOODS_PRICE  ... FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# 18250         135000.0  ...                0                0
# 23797        1800000.0  ...                0                0
# 39080         810000.0  ...                0                0
# 8456          675000.0  ...                0                0
# 48723         315000.0  ...                0                0
#
#       FLAG_DOCUMENT_20 FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR  \
# 18250                0                0                        0.0
# 23797                0                0                        0.0
# 39080                0                0                        0.0
# 8456                 0                0                        0.0
# 48723                0                0                        0.0
#
#        AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 18250                        0.0                         0.0
# 23797                        0.0                         0.0
# 39080                        0.0                         0.0
# 8456                         0.0                         0.0
# 48723                        0.0                         0.0
#
#        AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# 18250                        0.0                        1.0
# 23797                        0.0                        0.0
# 39080                        0.0                        0.0
# 8456                         0.0                        2.0
# 48723                        0.0                        1.0
#
#        AMT_REQ_CREDIT_BUREAU_YEAR
# 18250                         0.0
# 23797                         1.0
# 39080                         2.0
# 8456                          3.0
# 48723                         0.0
#
# [5 rows x 121 columns]

# %%
application_train.sample(5)
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 283841      428713       0         Cash loans           F            Y
# 16645       119417       0    Revolving loans           M            N
# 40543       146953       0    Revolving loans           M            N
# 17307       120186       0         Cash loans           M            Y
# 5894        106899       0         Cash loans           M            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 283841               N             0          225000.0    733315.5
# 16645                Y             0           72000.0    180000.0
# 40543                Y             0          157500.0    180000.0
# 17307                Y             0          225000.0   1305909.0
# 5894                 Y             0           45000.0     97038.0
#
#         AMT_ANNUITY  ...  FLAG_DOCUMENT_18 FLAG_DOCUMENT_19 FLAG_DOCUMENT_20  \
# 283841      42876.0  ...                 0                0                0
# 16645        9000.0  ...                 0                0                0
# 40543        9000.0  ...                 0                0                0
# 17307       43290.0  ...                 0                0                0
# 5894         5085.0  ...                 0                0                0
#
#        FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR AMT_REQ_CREDIT_BUREAU_DAY  \
# 283841                0                        0.0                       0.0
# 16645                 0                        0.0                       0.0
# 40543                 0                        0.0                       0.0
# 17307                 0                        0.0                       0.0
# 5894                  0                        NaN                       NaN
#
#         AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# 283841                         0.0                        0.0
# 16645                          0.0                        0.0
# 40543                          0.0                        0.0
# 17307                          0.0                        0.0
# 5894                           NaN                        NaN
#
#         AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# 283841                        0.0                         1.0
# 16645                         0.0                         0.0
# 40543                         2.0                         2.0
# 17307                         2.0                         5.0
# 5894                          NaN                         NaN
#
# [5 rows x 122 columns]

# %%
bureau_balance.sample(5)
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 9453105        5937720             -62      X
# 3999498        5791338             -64      0
# 27271884       5564154             -39      0
# 8481136        6409965             -51      0
# 22847025       6593458             -45      C

# %%
bureau.sample(5)
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 163240       397455       6252316        Closed      currency 1         -655
# 1351745      404590       5143499        Closed      currency 1        -2445
# 211640       401022       6579302        Closed      currency 1        -1225
# 123102       197018       5240594        Closed      currency 1        -1848
# 663705       111925       5015937        Active      currency 1         -287
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 163240                    0               -291.0             -520.0
# 1351745                   0              -2251.0            -1096.0
# 211640                    0                602.0             -616.0
# 123102                    0              -1466.0            -1466.0
# 663705                    0                255.0                NaN
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 163240                      0.0                   0         97146.0
# 1351745                     NaN                   0         16375.5
# 211640                      NaN                   0        238500.0
# 123102                      NaN                   0        225000.0
# 663705                      NaN                   0        361800.0
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 163240                   0.0                   0.0                     0.0
# 1351745                  NaN                   NaN                     0.0
# 211640                   0.0                   0.0                     0.0
# 123102                   0.0                   0.0                     0.0
# 663705                   NaN                   NaN                     0.0
#
#              CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 163240   Consumer credit                -449          NaN
# 1351745  Consumer credit               -1093          0.0
# 211640   Consumer credit                -281          0.0
# 123102   Consumer credit               -1370          NaN
# 663705   Consumer credit                  -7          NaN

# %%
credit_card_balance.sample(5)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 3791800     1030557      253050             -39        0.000
# 3799983     2507512      308784             -39   106761.375
# 3354126     1875222      299911              -6   432571.455
# 3515690     1643726      313568             -77   141794.280
# 1335448     2079350      168545             -79    51282.945
#
#          AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 3791800                        0                       0.0
# 3799983                   180000                       0.0
# 3354126                   427500                       0.0
# 3515690                   180000                    2250.0
# 1335448                    67500                   22500.0
#
#          AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# 3791800                 0.000                         0.0
# 3799983                 0.000                         0.0
# 3354126              6769.305                         0.0
# 3515690              2250.000                         0.0
# 1335448             22500.000                         0.0
#
#          AMT_DRAWINGS_POS_CURRENT  AMT_INST_MIN_REGULARITY  ...  \
# 3791800                     0.000                    0.000  ...
# 3799983                     0.000                 9000.000  ...
# 3354126                  6769.305                22154.265  ...
# 3515690                     0.000                 9000.000  ...
# 1335448                     0.000                 3375.000  ...
#
#          AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  \
# 3791800          0.000                 0.000                       0.0
# 3799983     106761.375            106761.375                       0.0
# 3354126     432571.455            432571.455                       0.0
# 3515690     141794.280            141794.280                       1.0
# 1335448      51282.945             51282.945                       1.0
#
#          CNT_DRAWINGS_CURRENT  CNT_DRAWINGS_OTHER_CURRENT  \
# 3791800                     0                         0.0
# 3799983                     0                         0.0
# 3354126                     7                         0.0
# 3515690                     1                         0.0
# 1335448                     1                         0.0
#
#          CNT_DRAWINGS_POS_CURRENT  CNT_INSTALMENT_MATURE_CUM  \
# 3791800                       0.0                       22.0
# 3799983                       0.0                       56.0
# 3354126                       7.0                       36.0
# 3515690                       0.0                       21.0
# 1335448                       0.0                        8.0
#
#          NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 3791800                Active       0           0
# 3799983                Active       0           0
# 3354126                Active       0           0
# 3515690                Active       0           0
# 1335448                Active       0           0
#
# [5 rows x 23 columns]

# %%
installments_payments.sample(5)
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 10443024     2583136      315912                     0.0
# 5506583      1443462      260646                     1.0
# 5303248      2343826      273760                     1.0
# 12219264     2665788      438647                     0.0
# 11536972     1211227      436674                     0.0
#
#           NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# 10443024                      2           -729.0              -733.0
# 5506583                       9          -1814.0             -1821.0
# 5303248                       4          -1130.0             -1136.0
# 12219264                     17           -144.0              -144.0
# 11536972                    103           -438.0              -438.0
#
#           AMT_INSTALMENT  AMT_PAYMENT
# 10443024        4548.330     4548.330
# 5506583         4390.335     4374.135
# 5303248         9655.110     9655.110
# 12219264        2151.495     2151.495
# 11536972          33.210       33.210

# %%
posh_cash_balance.sample(5)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 8493970     1336749      160209             -43            10.0
# 9126611     1577655      210156             -28            24.0
# 1399829     1240626      186728             -25             6.0
# 7036482     1950606      135598             -55            12.0
# 7399391     2633091      263325             -55            10.0
#
#          CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 8493970                    2.0               Active       0           0
# 9126611                    0.0            Completed       0           0
# 1399829                    3.0               Active       0           0
# 7036482                    0.0               Active     406           0
# 7399391                    7.0               Active       0           0

# %%
previous_application.sample(5)
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 1584606     1587937      303655         Cash loans          NaN
# 1142453     2412977      187488     Consumer loans    10148.265
# 521391      1164394      430503         Cash loans     7522.875
# 1208784     1246347      195124         Cash loans    34160.715
# 282714      2724419      443740         Cash loans    50026.005
#
#          AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 1584606              0.0         0.0               NaN              NaN
# 1142453          52515.0     49761.0            5251.5          52515.0
# 521391          162000.0    194076.0               NaN         162000.0
# 1208784         922500.0   1029658.5               NaN         922500.0
# 282714          900000.0    978408.0               NaN         900000.0
#
#         WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  ...  \
# 1584606                    TUESDAY                       14  ...
# 1142453                     FRIDAY                       13  ...
# 521391                      SUNDAY                       12  ...
# 1208784                    TUESDAY                       16  ...
# 282714                     TUESDAY                       14  ...
#
#         NAME_SELLER_INDUSTRY  CNT_PAYMENT  NAME_YIELD_GROUP  \
# 1584606                  XNA          NaN               XNA
# 1142453         Connectivity          6.0              high
# 521391                   XNA         36.0        low_normal
# 1208784                  XNA         48.0        low_normal
# 282714                   XNA         36.0            middle
#
#               PRODUCT_COMBINATION  DAYS_FIRST_DRAWING DAYS_FIRST_DUE  \
# 1584606                      Cash                 NaN            NaN
# 1142453  POS mobile with interest            365243.0         -324.0
# 521391           Cash X-Sell: low                 NaN            NaN
# 1208784          Cash X-Sell: low                 NaN            NaN
# 282714        Cash X-Sell: middle                 NaN            NaN
#
#         DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE DAYS_TERMINATION  \
# 1584606                       NaN            NaN              NaN
# 1142453                    -174.0         -174.0           -171.0
# 521391                        NaN            NaN              NaN
# 1208784                       NaN            NaN              NaN
# 282714                        NaN            NaN              NaN
#
#         NFLAG_INSURED_ON_APPROVAL
# 1584606                       NaN
# 1142453                       0.0
# 521391                        NaN
# 1208784                       NaN
# 282714                        NaN
#
# [5 rows x 37 columns]

# %%
sample_submission.sample(5)
# Out:
#        SK_ID_CURR  TARGET
# 20063      245766     0.5
# 5226       138107     0.5
# 46115      437169     0.5
# 12123      188045     0.5
# 10722      177875     0.5

# %%
application_train.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# 50%    5.135310e+05   24903.000000     4.500000e+05
# 75%    8.086500e+05   34596.000000     6.795000e+05
# max    4.050000e+06  258025.500000     4.050000e+06
#
#        REGION_POPULATION_RELATIVE     DAYS_BIRTH  DAYS_EMPLOYED  ...  \
# count               307511.000000  307511.000000  307511.000000  ...
# mean                     0.020868  -16036.995067   63815.045904  ...
# std                      0.013831    4363.988632  141275.766519  ...
# min                      0.000290  -25229.000000  -17912.000000  ...
# 25%                      0.010006  -19682.000000   -2760.000000  ...
# 50%                      0.018850  -15750.000000   -1213.000000  ...
# 75%                      0.028663  -12413.000000    -289.000000  ...
# max                      0.072508   -7489.000000  365243.000000  ...
#
#        FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# count     307511.000000     307511.000000     307511.000000     307511.000000
# mean           0.008130          0.000595          0.000507          0.000335
# std            0.089798          0.024387          0.022518          0.018299
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000          0.000000
# 75%            0.000000          0.000000          0.000000          0.000000
# max            1.000000          1.000000          1.000000          1.000000
#
#        AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# count               265992.000000              265992.000000
# mean                     0.006402                   0.007000
# std                      0.083849                   0.110757
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      4.000000                   9.000000
#
#        AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# count               265992.000000              265992.000000
# mean                     0.034362                   0.267395
# std                      0.204685                   0.916002
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      8.000000                  27.000000
#
#        AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# count              265992.000000               265992.000000
# mean                    0.265474                    1.899974
# std                     0.794056                    1.869295
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    1.000000
# 75%                     0.000000                    3.000000
# max                   261.000000                   25.000000
#
# [8 rows x 106 columns]

# %% [markdown]
# Info Kolom tiap Table

# %%
bureau.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1716428 entries, 0 to 1716427
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   SK_ID_CURR              int64
#  1   SK_ID_BUREAU            int64
#  2   CREDIT_ACTIVE           object
#  3   CREDIT_CURRENCY         object
#  4   DAYS_CREDIT             int64
#  5   CREDIT_DAY_OVERDUE      int64
#  6   DAYS_CREDIT_ENDDATE     float64
#  7   DAYS_ENDDATE_FACT       float64
#  8   AMT_CREDIT_MAX_OVERDUE  float64
#  9   CNT_CREDIT_PROLONG      int64
#  10  AMT_CREDIT_SUM          float64
#  11  AMT_CREDIT_SUM_DEBT     float64
#  12  AMT_CREDIT_SUM_LIMIT    float64
#  13  AMT_CREDIT_SUM_OVERDUE  float64
#  14  CREDIT_TYPE             object
#  15  DAYS_CREDIT_UPDATE      int64
#  16  AMT_ANNUITY             float64
# dtypes: float64(8), int64(6), object(3)
# memory usage: 222.6+ MB

# %%
bureau_balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27299925 entries, 0 to 27299924
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   SK_ID_BUREAU    int64
#  1   MONTHS_BALANCE  int64
#  2   STATUS          object
# dtypes: int64(2), object(1)
# memory usage: 624.8+ MB

# %%
credit_card_balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3840312 entries, 0 to 3840311
# Data columns (total 23 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   SK_ID_PREV                  int64
#  1   SK_ID_CURR                  int64
#  2   MONTHS_BALANCE              int64
#  3   AMT_BALANCE                 float64
#  4   AMT_CREDIT_LIMIT_ACTUAL     int64
#  5   AMT_DRAWINGS_ATM_CURRENT    float64
#  6   AMT_DRAWINGS_CURRENT        float64
#  7   AMT_DRAWINGS_OTHER_CURRENT  float64
#  8   AMT_DRAWINGS_POS_CURRENT    float64
#  9   AMT_INST_MIN_REGULARITY     float64
#  10  AMT_PAYMENT_CURRENT         float64
#  11  AMT_PAYMENT_TOTAL_CURRENT   float64
#  12  AMT_RECEIVABLE_PRINCIPAL    float64
#  13  AMT_RECIVABLE               float64
#  14  AMT_TOTAL_RECEIVABLE        float64
#  15  CNT_DRAWINGS_ATM_CURRENT    float64
#  16  CNT_DRAWINGS_CURRENT        int64
#  17  CNT_DRAWINGS_OTHER_CURRENT  float64
#  18  CNT_DRAWINGS_POS_CURRENT    float64
#  19  CNT_INSTALMENT_MATURE_CUM   float64
#  20  NAME_CONTRACT_STATUS        object
#  21  SK_DPD                      int64
#  22  SK_DPD_DEF                  int64
# dtypes: float64(15), int64(7), object(1)
# memory usage: 673.9+ MB

# %%
installments_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13605401 entries, 0 to 13605400
# Data columns (total 8 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   SK_ID_PREV              int64
#  1   SK_ID_CURR              int64
#  2   NUM_INSTALMENT_VERSION  float64
#  3   NUM_INSTALMENT_NUMBER   int64
#  4   DAYS_INSTALMENT         float64
#  5   DAYS_ENTRY_PAYMENT      float64
#  6   AMT_INSTALMENT          float64
#  7   AMT_PAYMENT             float64
# dtypes: float64(5), int64(3)
# memory usage: 830.4 MB

# %%
posh_cash_balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001358 entries, 0 to 10001357
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   SK_ID_PREV             int64
#  1   SK_ID_CURR             int64
#  2   MONTHS_BALANCE         int64
#  3   CNT_INSTALMENT         float64
#  4   CNT_INSTALMENT_FUTURE  float64
#  5   NAME_CONTRACT_STATUS   object
#  6   SK_DPD                 int64
#  7   SK_DPD_DEF             int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 610.4+ MB

# %%
previous_application.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
#  12  RATE_DOWN_PAYMENT            774370 non-null   float64
#  13  RATE_INTEREST_PRIMARY        5951 non-null     float64
#  14  RATE_INTEREST_PRIVILEGED     5951 non-null     float64
#  15  NAME_CASH_LOAN_PURPOSE       1670214 non-null  object
#  16  NAME_CONTRACT_STATUS         1670214 non-null  object
#  17  DAYS_DECISION                1670214 non-null  int64
#  18  NAME_PAYMENT_TYPE            1670214 non-null  object
#  19  CODE_REJECT_REASON           1670214 non-null  object
#  20  NAME_TYPE_SUITE              849809 non-null   object
#  21  NAME_CLIENT_TYPE             1670214 non-null  object
#  22  NAME_GOODS_CATEGORY          1670214 non-null  object
#  23  NAME_PORTFOLIO               1670214 non-null  object
#  24  NAME_PRODUCT_TYPE            1670214 non-null  object
#  25  CHANNEL_TYPE                 1670214 non-null  object
#  26  SELLERPLACE_AREA             1670214 non-null  int64
#  27  NAME_SELLER_INDUSTRY         1670214 non-null  object
#  28  CNT_PAYMENT                  1297984 non-null  float64
#  29  NAME_YIELD_GROUP             1670214 non-null  object
#  30  PRODUCT_COMBINATION          1669868 non-null  object
#  31  DAYS_FIRST_DRAWING           997149 non-null   float64
#  32  DAYS_FIRST_DUE               997149 non-null   float64
#  33  DAYS_LAST_DUE_1ST_VERSION    997149 non-null   float64
#  34  DAYS_LAST_DUE                997149 non-null   float64
#  35  DAYS_TERMINATION             997149 non-null   float64
#  36  NFLAG_INSURED_ON_APPROVAL    997149 non-null   float64
# dtypes: float64(15), int64(6), object(16)
# memory usage: 471.5+ MB

# %%
sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48744 entries, 0 to 48743
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SK_ID_CURR  48744 non-null  int64
#  1   TARGET      48744 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 761.8 KB

# %% [markdown]
# ### Combine Data

# %%
data = application_train.join(bureau, on = "SK_ID_CURR", how="left", rsuffix="_other").join(previous_application, on ="SK_ID_CURR", how="left", rsuffix="_prev")

# %% [markdown]
# Use column that we need

# %%
data_analysis = data[["SK_ID_CURR", "TARGET", "NAME_CONTRACT_TYPE","CODE_GENDER","FLAG_OWN_CAR","FLAG_OWN_REALTY","CNT_CHILDREN","AMT_INCOME_TOTAL", "AMT_CREDIT", "AMT_ANNUITY", "AMT_GOODS_PRICE",
"NAME_TYPE_SUITE", "NAME_INCOME_TYPE", "NAME_EDUCATION_TYPE", "NAME_FAMILY_STATUS", "NAME_HOUSING_TYPE", "FLAG_MOBIL", "FLAG_EMP_PHONE", "FLAG_WORK_PHONE", "FLAG_CONT_MOBILE", "FLAG_PHONE",
"FLAG_EMAIL", "OCCUPATION_TYPE", "CNT_FAM_MEMBERS", "CREDIT_ACTIVE","CREDIT_DAY_OVERDUE", "NAME_CONTRACT_STATUS"]]

# %%
data_analysis.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    ...  FLAG_EMP_PHONE FLAG_WORK_PHONE FLAG_CONT_MOBILE FLAG_PHONE FLAG_EMAIL  \
# 0  ...               1               0                1          1          0
# 1  ...               1               0                1          1          0
# 2  ...               1               1                1          1          0
# 3  ...               1               0                1          0          0
# 4  ...               1               0                1          0          0
#
#   OCCUPATION_TYPE  CNT_FAM_MEMBERS  CREDIT_ACTIVE  CREDIT_DAY_OVERDUE  \
# 0        Laborers              1.0         Closed                   0
# 1      Core staff              2.0         Closed                   0
# 2        Laborers              1.0         Closed                   0
# 3        Laborers              2.0         Closed                   0
# 4      Core staff              1.0         Closed                   0
#
#    NAME_CONTRACT_STATUS
# 0              Approved
# 1               Refused
# 2              Approved
# 3              Approved
# 4              Approved
#
# [5 rows x 27 columns]

# %% [markdown]
# Cek data describe berdasarkan type data

# %%
#numerical describe
describeNum = data_analysis.describe(include =['float64', 'int64', 'float', 'int'])
describeNum.T.style.background_gradient(cmap='viridis',low=0.2,high=0.1)
# Out:
# <style  type="text/css" >
# #T_8edbaf63_895a_11ec_af87_8030493be526row0_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row0_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row1_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row2_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row3_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row3_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row4_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row4_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row4_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row4_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row4_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row4_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row7_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row8_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row9_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row10_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row11_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row12_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row14_col0{
#             background-color:  #cde11d;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row0_col1{
#             background-color:  #20928c;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row0_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row3_col3{
#             background-color:  #2f6c8e;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row0_col4{
#             background-color:  #40bd72;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row0_col5{
#             background-color:  #1fa187;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row0_col6{
#             background-color:  #21918c;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row0_col7{
#             background-color:  #453781;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row1_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row1_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row1_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row1_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row1_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row1_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row1_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row2_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row2_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row2_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row2_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row2_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row2_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row2_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row5_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row6_col0,#T_8edbaf63_895a_11ec_af87_8030493be526row7_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row7_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row7_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row7_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row7_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row7_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row7_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row8_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row8_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row8_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row8_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row8_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row8_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row8_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row9_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row9_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row9_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row9_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row9_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row9_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row9_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row10_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row10_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row10_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row10_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row10_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row10_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row10_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row11_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row11_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row11_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row11_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row11_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row11_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row11_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row12_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row12_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row12_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row12_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row12_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row12_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row12_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row13_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row13_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row13_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row13_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row13_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row13_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row13_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row14_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row14_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row14_col3,#T_8edbaf63_895a_11ec_af87_8030493be526row14_col4,#T_8edbaf63_895a_11ec_af87_8030493be526row14_col5,#T_8edbaf63_895a_11ec_af87_8030493be526row14_col6,#T_8edbaf63_895a_11ec_af87_8030493be526row14_col7{
#             background-color:  #453581;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row3_col1{
#             background-color:  #2d718e;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row3_col2{
#             background-color:  #24aa83;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row3_col4{
#             background-color:  #238a8d;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row3_col5{
#             background-color:  #2c718e;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row3_col6{
#             background-color:  #2f6b8e;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row4_col3{
#             background-color:  #21908d;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row4_col7,#T_8edbaf63_895a_11ec_af87_8030493be526row5_col2,#T_8edbaf63_895a_11ec_af87_8030493be526row6_col7{
#             background-color:  #433e85;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row5_col0{
#             background-color:  #b5de2b;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row5_col1,#T_8edbaf63_895a_11ec_af87_8030493be526row5_col5{
#             background-color:  #424086;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row5_col3{
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row5_col4{
#             background-color:  #414487;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row5_col6{
#             background-color:  #423f85;
#             color:  #f1f1f1;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row6_col1{
#             background-color:  #98d83e;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row6_col2{
#             background-color:  #a2da37;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row6_col3{
#             background-color:  #23888e;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row6_col4{
#             background-color:  #90d743;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row6_col5{
#             background-color:  #8bd646;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row6_col6{
#             background-color:  #7ad151;
#             color:  #000000;
#         }#T_8edbaf63_895a_11ec_af87_8030493be526row13_col0{

# %%
#data object
data_object = data_analysis.select_dtypes(include="object")
data_object.describe()
# Out:
#        NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# count              307511      307511       307511          307511
# unique                  2           3            2               2
# top            Cash loans           F            N               Y
# freq               278232      202448       202924          213312
#
#        NAME_TYPE_SUITE NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# count           306219           307511                         307511
# unique               7                8                              5
# top      Unaccompanied          Working  Secondary / secondary special
# freq            248526           158774                         218391
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE OCCUPATION_TYPE CREDIT_ACTIVE  \
# count              307511             307511          211120        307511
# unique                  6                  6              18             4
# top               Married  House / apartment        Laborers        Closed
# freq               196432             272868           55186        194065
#
#        NAME_CONTRACT_STATUS
# count                307511
# unique                    4
# top                Approved
# freq                 190573

# %% [markdown]
# ### Cek Missing Data

# %%
data_analysis.shape
# Out:
# (307511, 27)

# %%
#pengecekan missing data di setiap feature
df_null = data_analysis.isnull().sum().reset_index()
df_null.columns = ["features", "missing_value"]
df_null
# Out:
#                 features  missing_value
# 0             SK_ID_CURR              0
# 1                 TARGET              0
# 2     NAME_CONTRACT_TYPE              0
# 3            CODE_GENDER              0
# 4           FLAG_OWN_CAR              0
# 5        FLAG_OWN_REALTY              0
# 6           CNT_CHILDREN              0
# 7       AMT_INCOME_TOTAL              0
# 8             AMT_CREDIT              0
# 9            AMT_ANNUITY             12
# 10       AMT_GOODS_PRICE            278
# 11       NAME_TYPE_SUITE           1292
# 12      NAME_INCOME_TYPE              0
# 13   NAME_EDUCATION_TYPE              0
# 14    NAME_FAMILY_STATUS              0
# 15     NAME_HOUSING_TYPE              0
# 16            FLAG_MOBIL              0
# 17        FLAG_EMP_PHONE              0
# 18       FLAG_WORK_PHONE              0
# 19      FLAG_CONT_MOBILE              0
# 20            FLAG_PHONE              0
# 21            FLAG_EMAIL              0
# 22       OCCUPATION_TYPE          96391
# 23       CNT_FAM_MEMBERS              2
# 24         CREDIT_ACTIVE              0
# 25    CREDIT_DAY_OVERDUE              0
# 26  NAME_CONTRACT_STATUS              0

# %%
#cek occupation type
data_analysis.OCCUPATION_TYPE.unique()
# Out:
# array(['Laborers', 'Core staff', 'Accountants', 'Managers', nan,
#        'Drivers', 'Sales staff', 'Cleaning staff', 'Cooking staff',
#        'Private service staff', 'Medicine staff', 'Security staff',
#        'High skill tech staff', 'Waiters/barmen staff',
#        'Low-skill Laborers', 'Realty agents', 'Secretaries', 'IT staff',
#        'HR staff'], dtype=object)

# %%
# set null data occupation to "non job"
data_analysis["OCCUPATION_TYPE"] = data_analysis["OCCUPATION_TYPE"].fillna("non job")
# Out:
# <ipython-input-144-47c7286921d4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_analysis["OCCUPATION_TYPE"] = data_analysis["OCCUPATION_TYPE"].fillna("non job")

# %%
#cek after update
data_analysis.shape
# Out:
# (307511, 27)

# %%
#pengecekan missing data di setiap feature
df_null = data_analysis.isnull().sum().reset_index()
df_null.columns = ["features", "missing_value"]
df_null
# Out:
#                 features  missing_value
# 0             SK_ID_CURR              0
# 1                 TARGET              0
# 2     NAME_CONTRACT_TYPE              0
# 3            CODE_GENDER              0
# 4           FLAG_OWN_CAR              0
# 5        FLAG_OWN_REALTY              0
# 6           CNT_CHILDREN              0
# 7       AMT_INCOME_TOTAL              0
# 8             AMT_CREDIT              0
# 9            AMT_ANNUITY             12
# 10       AMT_GOODS_PRICE            278
# 11       NAME_TYPE_SUITE           1292
# 12      NAME_INCOME_TYPE              0
# 13   NAME_EDUCATION_TYPE              0
# 14    NAME_FAMILY_STATUS              0
# 15     NAME_HOUSING_TYPE              0
# 16            FLAG_MOBIL              0
# 17        FLAG_EMP_PHONE              0
# 18       FLAG_WORK_PHONE              0
# 19      FLAG_CONT_MOBILE              0
# 20            FLAG_PHONE              0
# 21            FLAG_EMAIL              0
# 22       OCCUPATION_TYPE              0
# 23       CNT_FAM_MEMBERS              2
# 24         CREDIT_ACTIVE              0
# 25    CREDIT_DAY_OVERDUE              0
# 26  NAME_CONTRACT_STATUS              0

# %% [markdown]
# drop missing value

# %%
#delete missing values
data_analysis = data_analysis.dropna() 

#check if there is other missing value
data_analysis.isnull().sum()
# Out:
# SK_ID_CURR              0
# TARGET                  0
# NAME_CONTRACT_TYPE      0
# CODE_GENDER             0
# FLAG_OWN_CAR            0
# FLAG_OWN_REALTY         0
# CNT_CHILDREN            0
# AMT_INCOME_TOTAL        0
# AMT_CREDIT              0
# AMT_ANNUITY             0
# AMT_GOODS_PRICE         0
# NAME_TYPE_SUITE         0
# NAME_INCOME_TYPE        0
# NAME_EDUCATION_TYPE     0
# NAME_FAMILY_STATUS      0
# NAME_HOUSING_TYPE       0
# FLAG_MOBIL              0
# FLAG_EMP_PHONE          0
# FLAG_WORK_PHONE         0
# FLAG_CONT_MOBILE        0
# FLAG_PHONE              0
# FLAG_EMAIL              0
# OCCUPATION_TYPE         0
# CNT_FAM_MEMBERS         0
# CREDIT_ACTIVE           0
# CREDIT_DAY_OVERDUE      0
# NAME_CONTRACT_STATUS    0
# dtype: int64

# %%
data_analysis.shape
# Out:
# (306207, 27)

# %% [markdown]
# ### Cek Duplicate Data

# %%
#check total duplicate data
data_analysis.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there is no duplicate data , so we can do next process

# %% [markdown]
# ### Cek Persebaran Data

# %% [markdown]
# Data Numerical

# %%
data_num = data_analysis.select_dtypes(include="number")
len(data_num.columns)
# Out:
# 15

# %%
data_num = data_num
k = len(data_num.columns)
n = 3
m = k // n
fig, axes = plt.subplots(m, n, figsize=(n * 5, m * 3))
for i, (name, col) in enumerate(data_num.iteritems()):
    r, c = i // n, i % n
    axe = axes[r, c]
    sns.kdeplot(x = col, color='green', data=data_num, ax=axe)

fig.tight_layout()

# %% [markdown]
# in data distribution we know mayority data have skew distribution
# "Target" is target

# %% [markdown]
# Data Categorical

# %%
data_cat_unique = data_object.nunique().reset_index()
data_cat_unique.columns = ['feature', 'unique value']
data_cat_unique = data_cat_unique.sort_values('unique value', ascending=False)
data_cat_unique
# Out:
#                  feature  unique value
# 9        OCCUPATION_TYPE            18
# 5       NAME_INCOME_TYPE             8
# 4        NAME_TYPE_SUITE             7
# 7     NAME_FAMILY_STATUS             6
# 8      NAME_HOUSING_TYPE             6
# 6    NAME_EDUCATION_TYPE             5
# 10         CREDIT_ACTIVE             4
# 11  NAME_CONTRACT_STATUS             4
# 1            CODE_GENDER             3
# 0     NAME_CONTRACT_TYPE             2
# 2           FLAG_OWN_CAR             2
# 3        FLAG_OWN_REALTY             2

# %% [markdown]
# Terdapat data yang memiliki unique data yang besar

# %% [markdown]
# ### Data Relationship

# %%
# data object
category = list(data_object.columns)
k = len(category)
n = 3
m = k // n
fig, axes = plt.subplots(m, n, figsize=(n * 7, m * 4))
for i in range(0,len(category)):
    r, c = i // n, i % n
    axe = axes[r, c]
    chart = sns.countplot( x= category[i], hue = "TARGET", data=data_analysis, ax=axe)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=35)
    plt.tight_layout()

# %%
#data ordinal
ordinal = list()
for i in data_num.columns:
    if data_num[i].nunique() < 20:
        ordinal.append(i)
ordinal.remove("TARGET")

# %%
ordinal
# Out:
# ['CNT_CHILDREN',
#  'FLAG_MOBIL',
#  'FLAG_EMP_PHONE',
#  'FLAG_WORK_PHONE',
#  'FLAG_CONT_MOBILE',
#  'FLAG_PHONE',
#  'FLAG_EMAIL',
#  'CNT_FAM_MEMBERS']

# %%
# data Ordinal with Target
k = len(ordinal)
n = 3
m = (k + 1) // n
fig, axes = plt.subplots(m, n, figsize=(n * 7, m * 4))
for i in range(0,len(ordinal)):
    r, c = i // n, i % n
    axe = axes[r, c]
    chart = sns.countplot( x= ordinal[i], hue = "TARGET", data=data_analysis, ax=axe)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=35)
    plt.tight_layout()

# %%
# numeric
numerik = list()
for i in data_num.columns:
    if i != "TARGET":
        if i not in ordinal:
            numerik.append(i)
numerik
# Out:
# ['SK_ID_CURR',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'CREDIT_DAY_OVERDUE']

# %%
# data numeric
k = len(numerik)
n = 2
m = k // n
fig, axes = plt.subplots(m, n, figsize=(n * 7, m * 4))
for i in range(0,len(numerik)):
    r, c = i // n, i % n
    axe = axes[r, c]
    chart = sns.kdeplot( x= numerik[i], hue = "TARGET", data=data_analysis, ax=axe)
    plt.tight_layout()

# %% [markdown]
# data lebih skew ke kiri ( perlu dilakukan standarisasi data )

# %% [markdown]
# ### Change data object to Numeric

# %%
data_all = data_analysis.replace({"NAME_CONTRACT_TYPE":{"Cash loans":0 , "Revolving loans":1} , "CODE_GENDER":{"M":0,"F":1, "XNA":1},
                                 "FLAG_OWN_CAR":{"N":0,"Y":1}, "FLAG_OWN_REALTY":{"N":0,"Y":1} , "NAME_CONTRACT_STATUS" : {"Approved": 1, "Refused" : 0, "Canceled": 0, "Unused offer" : 0 } ,
                                 "CREDIT_ACTIVE" : {"Closed": 0, "Active" : 1, "Sold": 0, "Bad debt" : 1 } }) 
data_all.head()
# Out:
#    SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_CAR  \
# 0      100002       1                   0            0             0
# 1      100003       0                   0            1             0
# 2      100004       0                   1            0             1
# 3      100006       0                   0            1             0
# 4      100007       0                   0            0             0
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0                1             0          202500.0    406597.5      24700.5
# 1                0             0          270000.0   1293502.5      35698.5
# 2                1             0           67500.0    135000.0       6750.0
# 3                1             0          135000.0    312682.5      29686.5
# 4                1             0          121500.0    513000.0      21865.5
#
#    ...  FLAG_EMP_PHONE FLAG_WORK_PHONE FLAG_CONT_MOBILE FLAG_PHONE FLAG_EMAIL  \
# 0  ...               1               0                1          1          0
# 1  ...               1               0                1          1          0
# 2  ...               1               1                1          1          0
# 3  ...               1               0                1          0          0
# 4  ...               1               0                1          0          0
#
#   OCCUPATION_TYPE  CNT_FAM_MEMBERS  CREDIT_ACTIVE  CREDIT_DAY_OVERDUE  \
# 0        Laborers              1.0              0                   0
# 1      Core staff              2.0              0                   0
# 2        Laborers              1.0              0                   0
# 3        Laborers              2.0              0                   0
# 4      Core staff              1.0              0                   0
#
#    NAME_CONTRACT_STATUS
# 0                     1
# 1                     0
# 2                     1
# 3                     1
# 4                     1
#
# [5 rows x 27 columns]

# %%
data_all.CODE_GENDER.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data_all.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE',
#        'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',
#        'NAME_HOUSING_TYPE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE',
#        'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'CREDIT_ACTIVE', 'CREDIT_DAY_OVERDUE',
#        'NAME_CONTRACT_STATUS'],
#       dtype='object')

# %%
#Make Phone ownership
def telepon(data):
    if data["FLAG_EMP_PHONE"] == 1 or data["FLAG_WORK_PHONE"] == 1 or data["FLAG_CONT_MOBILE"] == 1 or data["FLAG_PHONE"] == 1 or data["FLAG_MOBIL"] == 1:
        return 1
    else :
        return 0

# %%
data_all["PHONE"] = data_all.apply(telepon , axis = 1)
data_all.drop(columns=["FLAG_EMP_PHONE","FLAG_WORK_PHONE","FLAG_CONT_MOBILE","FLAG_PHONE"] , inplace=True)

# %%
#Accompanied
def accompanied(data):
    if data == "Unaccompanied":
        return 0
    else:
        return 1

# %%
data_all.NAME_TYPE_SUITE = data_all.NAME_TYPE_SUITE.apply(accompanied)

# %%
#Marriage
def marriage(data):
    if data == "Married" or data == "Civil marriage":
        return 1
    else:
        return 0

# %%
data_all.NAME_FAMILY_STATUS = data_all.NAME_FAMILY_STATUS.apply(marriage)

# %%
#Working
def working(data):
    kerja = ["Working", "State servant", "Commercial associate"]
    if data in kerja:
        return 1
    else :
        return 0

# %%
data_all["NAME_INCOME_TYPE"] = data_all.NAME_INCOME_TYPE.apply(working)

# %%
#Have House
def house(data):
    if data == "House / apartment":
        return 1
    else :
        return 0

# %%
data_all["NAME_HOUSING_TYPE"] = data_all.NAME_HOUSING_TYPE.apply(house)

# %%
#Have Skill Education
def edu(data):
    if data == "Academic degree" or data == "Higher education":
        return 1
    else :
        return 0

# %%
data_all["NAME_EDUCATION_TYPE"] = data_all.NAME_EDUCATION_TYPE.apply(edu)

# %%
# Drop Occupation Type
data_all.drop(columns = ["OCCUPATION_TYPE", "FLAG_MOBIL", "NAME_HOUSING_TYPE"], inplace = True)

# %%
data_all.head()
# Out:
#    SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_CAR  \
# 0      100002       1                   0            0             0
# 1      100003       0                   0            1             0
# 2      100004       0                   1            0             1
# 3      100006       0                   0            1             0
# 4      100007       0                   0            0             0
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0                1             0          202500.0    406597.5      24700.5
# 1                0             0          270000.0   1293502.5      35698.5
# 2                1             0           67500.0    135000.0       6750.0
# 3                1             0          135000.0    312682.5      29686.5
# 4                1             0          121500.0    513000.0      21865.5
#
#    ...  NAME_TYPE_SUITE  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0  ...                0                 1                    0
# 1  ...                1                 1                    1
# 2  ...                0                 1                    0
# 3  ...                0                 1                    0
# 4  ...                0                 1                    0
#
#    NAME_FAMILY_STATUS  FLAG_EMAIL  CNT_FAM_MEMBERS  CREDIT_ACTIVE  \
# 0                   0           0              1.0              0
# 1                   1           0              2.0              0
# 2                   0           0              1.0              0
# 3                   1           0              2.0              0
# 4                   0           0              1.0              0
#
#    CREDIT_DAY_OVERDUE  NAME_CONTRACT_STATUS  PHONE
# 0                   0                     1      1
# 1                   0                     0      1
# 2                   0                     1      1
# 3                   0                     1      1
# 4                   0                     1      1
#
# [5 rows x 21 columns]

# %%
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306207 entries, 0 to 307510
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   SK_ID_CURR            306207 non-null  int64
#  1   TARGET                306207 non-null  int64
#  2   NAME_CONTRACT_TYPE    306207 non-null  int64
#  3   CODE_GENDER           306207 non-null  int64
#  4   FLAG_OWN_CAR          306207 non-null  int64
#  5   FLAG_OWN_REALTY       306207 non-null  int64
#  6   CNT_CHILDREN          306207 non-null  int64
#  7   AMT_INCOME_TOTAL      306207 non-null  float64
#  8   AMT_CREDIT            306207 non-null  float64
#  9   AMT_ANNUITY           306207 non-null  float64
#  10  AMT_GOODS_PRICE       306207 non-null  float64
#  11  NAME_TYPE_SUITE       306207 non-null  int64
#  12  NAME_INCOME_TYPE      306207 non-null  int64
#  13  NAME_EDUCATION_TYPE   306207 non-null  int64
#  14  NAME_FAMILY_STATUS    306207 non-null  int64
#  15  FLAG_EMAIL            306207 non-null  int64
#  16  CNT_FAM_MEMBERS       306207 non-null  float64
#  17  CREDIT_ACTIVE         306207 non-null  int64
#  18  CREDIT_DAY_OVERDUE    306207 non-null  int64
#  19  NAME_CONTRACT_STATUS  306207 non-null  int64
#  20  PHONE                 306207 non-null  int64
# dtypes: float64(5), int64(16)
# memory usage: 61.4 MB

# %%
data_all.set_axis(["Id", "Status", "Contract_Type", "Gender", "Own_Car", "Own_Realty", "Cnt_Children", "Total_Income", "Total_Credit",
                 "Annuity", "Good_Price", "Accompany","Working", "Education", "Marriage", "Email", "Fam_Member", "Other_Credit", "Overdue_Credit",
                 "History_Credit", "Have_Phone"], axis = 1, inplace=True)

# %%
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306207 entries, 0 to 307510
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Id              306207 non-null  int64
#  1   Status          306207 non-null  int64
#  2   Contract_Type   306207 non-null  int64
#  3   Gender          306207 non-null  int64
#  4   Own_Car         306207 non-null  int64
#  5   Own_Realty      306207 non-null  int64
#  6   Cnt_Children    306207 non-null  int64
#  7   Total_Income    306207 non-null  float64
#  8   Total_Credit    306207 non-null  float64
#  9   Annuity         306207 non-null  float64
#  10  Good_Price      306207 non-null  float64
#  11  Accompany       306207 non-null  int64
#  12  Working         306207 non-null  int64
#  13  Education       306207 non-null  int64
#  14  Marriage        306207 non-null  int64
#  15  Email           306207 non-null  int64
#  16  Fam_Member      306207 non-null  float64
#  17  Other_Credit    306207 non-null  int64
#  18  Overdue_Credit  306207 non-null  int64
#  19  History_Credit  306207 non-null  int64
#  20  Have_Phone      306207 non-null  int64
# dtypes: float64(5), int64(16)
# memory usage: 61.4 MB

# %%
working_user = data_all[data_all["Working"] == 1]
working_user.describe()
# Out:
#                   Id         Status  Contract_Type         Gender  \
# count  250989.000000  250989.000000  250989.000000  250989.000000
# mean   278098.737315       0.086745       0.102104       0.623521
# std    102813.121073       0.281461       0.302786       0.484503
# min    100002.000000       0.000000       0.000000       0.000000
# 25%    189021.000000       0.000000       0.000000       0.000000
# 50%    278043.000000       0.000000       0.000000       1.000000
# 75%    367165.000000       0.000000       0.000000       1.000000
# max    456255.000000       1.000000       1.000000       1.000000
#
#              Own_Car     Own_Realty   Cnt_Children  Total_Income  \
# count  250989.000000  250989.000000  250989.000000  2.509890e+05
# mean        0.374610       0.679994       0.498556  1.758824e+05
# std         0.484023       0.466479       0.763202  2.592896e+05
# min         0.000000       0.000000       0.000000  2.565000e+04
# 25%         0.000000       0.000000       0.000000  1.125000e+05
# 50%         0.000000       1.000000       0.000000  1.575000e+05
# 75%         1.000000       1.000000       1.000000  2.115000e+05
# max         1.000000       1.000000      19.000000  1.170000e+08
#
#        Total_Credit        Annuity  ...      Accompany   Working  \
# count  2.509890e+05  250989.000000  ...  250989.000000  250989.0
# mean   6.109999e+05   27822.822335  ...       0.183335       1.0
# std    4.058159e+05   14635.615782  ...       0.386941       0.0
# min    4.500000e+04    1980.000000  ...       0.000000       1.0
# 25%    2.779695e+05   17086.500000  ...       0.000000       1.0
# 50%    5.212800e+05   25843.500000  ...       0.000000       1.0
# 75%    8.280000e+05   35617.500000  ...       0.000000       1.0
# max    4.050000e+06  258025.500000  ...       1.000000       1.0
#
#            Education       Marriage          Email     Fam_Member  \
# count  250989.000000  250989.000000  250989.000000  250989.000000
# mean        0.264466       0.754133       0.063580       2.252688
# std         0.441049       0.430601       0.244005       0.942089
# min         0.000000       0.000000       0.000000       1.000000
# 25%         0.000000       1.000000       0.000000       2.000000
# 50%         0.000000       1.000000       0.000000       2.000000
# 75%         1.000000       1.000000       0.000000       3.000000
# max         1.000000       1.000000       1.000000      20.000000
#
#         Other_Credit  Overdue_Credit  History_Credit  Have_Phone
# count  250989.000000   250989.000000   250989.000000    250989.0
# mean        0.365359        0.643371        0.619565         1.0
# std         0.481532       31.638254        0.485495         0.0
# min         0.000000        0.000000        0.000000         1.0
# 25%         0.000000        0.000000        0.000000         1.0
# 50%         0.000000        0.000000        1.000000         1.0
# 75%         1.000000        0.000000        1.000000         1.0
# max         1.000000     2693.000000        1.000000         1.0
#
# [8 rows x 21 columns]

# %% [markdown]
# Check Data Correlation with Heatmap

# %%
#data correlation
#check feature correlation
corelation = data_all.corr()
corelation
# Out:
#                       Id    Status  Contract_Type    Gender   Own_Car  \
# Id              1.000000 -0.002153       0.001348  0.000702  0.001344
# Status         -0.002153  1.000000      -0.031180 -0.055006 -0.021785
# Contract_Type   0.001348 -0.031180       1.000000  0.008569  0.006225
# Gender          0.000702 -0.055006       0.008569  1.000000 -0.346078
# Own_Car         0.001344 -0.021785       0.006225 -0.346078  1.000000
# Own_Realty      0.000591 -0.006690       0.065985  0.044215 -0.002082
# Cnt_Children   -0.001280  0.019271       0.029654 -0.047413  0.102201
# Total_Income   -0.001755 -0.003920      -0.003008 -0.074579  0.083047
# Total_Credit   -0.000205 -0.030310      -0.220719 -0.021172  0.115379
# Annuity        -0.000251 -0.012813      -0.240625 -0.076883  0.140895
# Good_Price     -0.000216 -0.039583      -0.186076 -0.022133  0.119940
# Accompany      -0.000433 -0.007538      -0.012942  0.008480  0.009598
# Working        -0.001373  0.046151       0.054006 -0.157285  0.154870
# Education      -0.000314 -0.056828       0.063163  0.016049  0.092978
# Marriage       -0.004025 -0.012394      -0.025655 -0.088549  0.142407
# Email           0.000194 -0.001706      -0.011119 -0.018420  0.032334
# Fam_Member     -0.002965  0.009280       0.011094 -0.080475  0.150002
# Other_Credit   -0.001604  0.000285       0.000932 -0.001543  0.000546
# Overdue_Credit  0.002336 -0.000898      -0.000764  0.000160 -0.000306
# History_Credit -0.012296 -0.001231      -0.000168  0.001447  0.000605
# Have_Phone           NaN       NaN            NaN       NaN       NaN
#
#                 Own_Realty  Cnt_Children  Total_Income  Total_Credit  \
# Id                0.000591     -0.001280     -0.001755     -0.000205
# Status           -0.006690      0.019271     -0.003920     -0.030310
# Contract_Type     0.065985      0.029654     -0.003008     -0.220719
# Gender            0.044215     -0.047413     -0.074579     -0.021172
# Own_Car          -0.002082      0.102201      0.083047      0.115379
# Own_Realty        1.000000     -0.002582      0.003338     -0.037505
# Cnt_Children     -0.002582      1.000000      0.012894      0.002088
# Total_Income      0.003338      0.012894      1.000000      0.156150
# Total_Credit     -0.037505      0.002088      0.156150      1.000000
# Annuity          -0.005011      0.021478      0.191061      0.769937
# Good_Price       -0.044055     -0.002030      0.159047      0.986975
# Accompany         0.055921      0.025779     -0.015151      0.025676
# Working          -0.069935      0.240714      0.063729      0.064717
# Education        -0.014071      0.033653      0.095300      0.127641
# Marriage          0.018857      0.177961      0.012514      0.126985
# Email             0.028982      0.022461      0.038382      0.016902
# Fam_Member        0.007083      0.879185      0.016285      0.063143
# Other_Credit      0.000747     -0.002441     -0.000396      0.000786
# Overdue_Credit   -0.000027      0.001399     -0.001220     -0.001764
# History_Credit    0.003831      0.000234     -0.002406      0.000760
# Have_Phone             NaN           NaN           NaN           NaN
#
#                  Annuity  ...  Accompany   Working  Education  Marriage  \
# Id             -0.000251  ...  -0.000433 -0.001373  -0.000314 -0.004025
# Status         -0.012813  ...  -0.007538  0.046151  -0.056828 -0.012394
# Contract_Type  -0.240625  ...  -0.012942  0.054006   0.063163 -0.025655
# Gender         -0.076883  ...   0.008480 -0.157285   0.016049 -0.088549
# Own_Car         0.140895  ...   0.009598  0.154870   0.092978  0.142407
# Own_Realty     -0.005011  ...   0.055921 -0.069935  -0.014071  0.018857
# Cnt_Children    0.021478  ...   0.025779  0.240714   0.033653  0.177961
# Total_Income    0.191061  ...  -0.015151  0.063729   0.095300  0.012514
# Total_Credit    0.769937  ...   0.025676  0.064717   0.127641  0.126985
# Annuity         1.000000  ...   0.021361  0.103093   0.144714  0.120946
# Good_Price      0.775089  ...   0.024535  0.062482   0.140707  0.129475
# Accompany       0.021361  ...   1.000000 -0.027663  -0.038462  0.089034
# Working         0.103093  ...  -0.027663  1.000000   0.103903  0.088757
# Education       0.144714  ...  -0.038462  0.103903   1.000000 -0.003077
# Marriage        0.120946  ...   0.089034  0.088757  -0.003077  1.000000
# Email           0.071948  ...  -0.009837  0.062505   0.077794  0.000195
# Fam_Member      0.075596  ...   0.063554  0.233867   0.025198  0.625336
# Other_Credit   -0.001294  ...  -0.000928  0.001596   0.003396  0.000891
# Overdue_Credit -0.003101  ...  -0.001619 -0.003650   0.002606 -0.002611
# History_Credit  0.001558  ...   0.003746 -0.000098  -0.002403  0.003264
# Have_Phone           NaN  ...        NaN       NaN        NaN       NaN
#
#                    Email  Fam_Member  Other_Credit  Overdue_Credit  \
# Id              0.000194   -0.002965     -0.001604        0.002336
# Status         -0.001706    0.009280      0.000285       -0.000898
# Contract_Type  -0.011119    0.011094      0.000932       -0.000764
# Gender         -0.018420   -0.080475     -0.001543        0.000160
# Own_Car         0.032334    0.150002      0.000546       -0.000306
# Own_Realty      0.028982    0.007083      0.000747       -0.000027
# Cnt_Children    0.022461    0.879185     -0.002441        0.001399
# Total_Income    0.038382    0.016285     -0.000396       -0.001220
# Total_Credit    0.016902    0.063143      0.000786       -0.001764
# Annuity         0.071948    0.075596     -0.001294       -0.003101
# Good_Price      0.017273    0.061083      0.000894       -0.001674
# Accompany      -0.009837    0.063554     -0.000928       -0.001619
# Working         0.062505    0.233867      0.001596       -0.003650
# Education       0.077794    0.025198      0.003396        0.002606
# Marriage        0.000195    0.625336      0.000891       -0.002611
# Email           1.000000    0.017907     -0.002072        0.003645
# Fam_Member      0.017907    1.000000     -0.001504       -0.000155
# Other_Credit   -0.002072   -0.001504      1.000000        0.018723
# Overdue_Credit  0.003645   -0.000155      0.018723        1.000000
# History_Credit  0.001155    0.001766     -0.001917       -0.000191
# Have_Phone           NaN         NaN           NaN             NaN
#
#                 History_Credit  Have_Phone
# Id                   -0.012296         NaN
# Status               -0.001231         NaN
# Contract_Type        -0.000168         NaN
# Gender                0.001447         NaN
# Own_Car               0.000605         NaN
# Own_Realty            0.003831         NaN
# Cnt_Children          0.000234         NaN
# Total_Income         -0.002406         NaN
# Total_Credit          0.000760         NaN
# Annuity               0.001558         NaN
# Good_Price            0.001010         NaN
# Accompany             0.003746         NaN
# Working              -0.000098         NaN
# Education            -0.002403         NaN
# Marriage              0.003264         NaN
# Email                 0.001155         NaN
# Fam_Member            0.001766         NaN
# Other_Credit         -0.001917         NaN
# Overdue_Credit       -0.000191         NaN
# History_Credit        1.000000         NaN
# Have_Phone                 NaN         NaN
#
# [21 rows x 21 columns]

# %%
#use heatmap to show the correlation
plt.figure(figsize=(15,10))
sns.heatmap(corelation, annot=True, fmt = ".2f", cmap = "BuPu" )
# Out:
# <AxesSubplot:>

# %% [markdown]
# We Can drop 3 column
# 1. Annuity
# 2. Good Price
# 3. Cnt_Children

# %%
#drop data
data_all.drop(columns = ["Annuity", "Good_Price", "Fam_Member"], inplace=True)
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306207 entries, 0 to 307510
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Id              306207 non-null  int64
#  1   Status          306207 non-null  int64
#  2   Contract_Type   306207 non-null  int64
#  3   Gender          306207 non-null  int64
#  4   Own_Car         306207 non-null  int64
#  5   Own_Realty      306207 non-null  int64
#  6   Cnt_Children    306207 non-null  int64
#  7   Total_Income    306207 non-null  float64
#  8   Total_Credit    306207 non-null  float64
#  9   Accompany       306207 non-null  int64
#  10  Working         306207 non-null  int64
#  11  Education       306207 non-null  int64
#  12  Marriage        306207 non-null  int64
#  13  Email           306207 non-null  int64
#  14  Other_Credit    306207 non-null  int64
#  15  Overdue_Credit  306207 non-null  int64
#  16  History_Credit  306207 non-null  int64
#  17  Have_Phone      306207 non-null  int64
# dtypes: float64(2), int64(16)
# memory usage: 54.4 MB

# %%
data_check = data_all.drop(columns = ["Id","Status"])
data_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306207 entries, 0 to 307510
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Contract_Type   306207 non-null  int64
#  1   Gender          306207 non-null  int64
#  2   Own_Car         306207 non-null  int64
#  3   Own_Realty      306207 non-null  int64
#  4   Cnt_Children    306207 non-null  int64
#  5   Total_Income    306207 non-null  float64
#  6   Total_Credit    306207 non-null  float64
#  7   Accompany       306207 non-null  int64
#  8   Working         306207 non-null  int64
#  9   Education       306207 non-null  int64
#  10  Marriage        306207 non-null  int64
#  11  Email           306207 non-null  int64
#  12  Other_Credit    306207 non-null  int64
#  13  Overdue_Credit  306207 non-null  int64
#  14  History_Credit  306207 non-null  int64
#  15  Have_Phone      306207 non-null  int64
# dtypes: float64(2), int64(14)
# memory usage: 49.7 MB

# %%
# data Ordinal with Target
k = len(data_check.columns)
n = 3
m = (k + 2) // n
fig, axes = plt.subplots(m, n, figsize=(n * 7, m * 4))
for i in range(0,len(data_check.columns)):
    r, c = i // n, i % n
    axe = axes[r, c]
    chart = sns.countplot( x= data_check.columns[i], hue = "Status", data=data_all, ax=axe)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=35)
    plt.tight_layout()

# %% [markdown]
# get data that have :
# 1. user have phone
# 2. user dont have email

# %%
data_all = data_all[data_all["Email"] == 0]
data_all = data_all.drop(columns=["Have_Phone","Email"])

# %%
data_check = data_all.drop(columns = ["Id","Status"])
data_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288816 entries, 0 to 307510
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Contract_Type   288816 non-null  int64
#  1   Gender          288816 non-null  int64
#  2   Own_Car         288816 non-null  int64
#  3   Own_Realty      288816 non-null  int64
#  4   Cnt_Children    288816 non-null  int64
#  5   Total_Income    288816 non-null  float64
#  6   Total_Credit    288816 non-null  float64
#  7   Accompany       288816 non-null  int64
#  8   Working         288816 non-null  int64
#  9   Education       288816 non-null  int64
#  10  Marriage        288816 non-null  int64
#  11  Other_Credit    288816 non-null  int64
#  12  Overdue_Credit  288816 non-null  int64
#  13  History_Credit  288816 non-null  int64
# dtypes: float64(2), int64(12)
# memory usage: 33.1 MB

# %%
# data Ordinal with Target
k = len(data_check.columns)
n = 3
m = (k + 2) // n
fig, axes = plt.subplots(m, n, figsize=(n * 7, m * 4))
for i in range(0,len(data_check.columns)):
    r, c = i // n, i % n
    axe = axes[r, c]
    chart = sns.kdeplot( x= data_check.columns[i], data=data_all, ax=axe)
    plt.tight_layout()

# %%
data_all.describe()
# Out:
#                   Id         Status  Contract_Type         Gender  \
# count  288816.000000  288816.000000  288816.000000  288816.000000
# mean   278160.043775       0.080958       0.095486       0.660649
# std    102841.787584       0.272771       0.293886       0.473490
# min    100002.000000       0.000000       0.000000       0.000000
# 25%    189038.750000       0.000000       0.000000       0.000000
# 50%    278160.500000       0.000000       0.000000       1.000000
# 75%    367176.250000       0.000000       0.000000       1.000000
# max    456255.000000       1.000000       1.000000       1.000000
#
#              Own_Car     Own_Realty   Cnt_Children  Total_Income  \
# count  288816.000000  288816.000000  288816.000000  2.888160e+05
# mean        0.336436       0.691821       0.413045  1.665455e+05
# std         0.472491       0.461742       0.720698  2.424925e+05
# min         0.000000       0.000000       0.000000  2.565000e+04
# 25%         0.000000       0.000000       0.000000  1.125000e+05
# 50%         0.000000       1.000000       0.000000  1.440000e+05
# 75%         1.000000       1.000000       1.000000  2.025000e+05
# max         1.000000       1.000000      19.000000  1.170000e+08
#
#        Total_Credit      Accompany        Working      Education  \
# count  2.888160e+05  288816.000000  288816.000000  288816.000000
# mean   5.971312e+05       0.189352       0.813774       0.235354
# std    4.006203e+05       0.391789       0.389289       0.424221
# min    4.500000e+04       0.000000       0.000000       0.000000
# 25%    2.700000e+05       0.000000       1.000000       0.000000
# 50%    5.121450e+05       0.000000       1.000000       0.000000
# 75%    8.086500e+05       0.000000       1.000000       0.000000
# max    4.050000e+06       1.000000       1.000000       1.000000
#
#             Marriage   Other_Credit  Overdue_Credit  History_Credit
# count  288816.000000  288816.000000   288816.000000   288816.000000
# mean        0.735756       0.365243        0.670427        0.619450
# std         0.440931       0.481499       32.254538        0.485523
# min         0.000000       0.000000        0.000000        0.000000
# 25%         0.000000       0.000000        0.000000        0.000000
# 50%         1.000000       0.000000        0.000000        1.000000
# 75%         1.000000       1.000000        0.000000        1.000000
# max         1.000000       1.000000     2693.000000        1.000000

# %% [markdown]
# ### Check Class Imbalance

# %%
sns.countplot(x = "Status", data = data_all)
# Out:
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %% [markdown]
# get 1% of data with status = 0
# do undersampling, so data that we have are real data

# %%
#install imblearn
##! pip install imblearn

# %%
from collections import Counter
print(sorted(Counter(data_all["Status"]).items()))
# Out:
# [(0, 265434), (1, 23382)]

# %%
#split data
X = data_all.drop(columns = ["Id","Status"])
Y = data_all["Status"]

# %%
#undersampling
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=0)
x_resampler , y_resampler = rus.fit_resample(X,Y)
print(sorted(Counter(y_resampler).items()), y_resampler.shape)
# Out:
# [(0, 23382), (1, 23382)] (46764,)

# %% [markdown]
# ### Separated Data

# %%
X = x_resampler
Y = y_resampler

# %%
# membagi dataframe menjadi data train dan data test
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state = 42)

# %% [markdown]
# ### Modeling

# %% [markdown]
# Logistic Regression

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, auc

def eval_classification(model, pred, xtrain, ytrain, xtest, ytest):
    print("Accuracy (Test Set): %.2f" % accuracy_score(ytest, pred))
    print("Precision (Test Set): %.2f" % precision_score(ytest, pred))
    print("Recall (Test Set): %.2f" % recall_score(ytest, pred))
    print("F1-Score (Test Set): %.2f" % f1_score(ytest, pred))
    
    fpr, tpr, thresholds = roc_curve(ytest, pred, pos_label=1) # pos_label: label yang kita anggap positive
    print("AUC: %.2f" % auc(fpr, tpr))
def show_feature_importance(model):
    feat_importances = pd.Series(model.feature_importances_, index=X.columns)
    ax = feat_importances.nlargest(25).plot(kind='barh', figsize=(10, 8))
    ax.invert_yaxis()

    plt.xlabel('score')
    plt.ylabel('feature')
    plt.title('feature importance score')

def show_best_hyperparameter(model, hyperparameters):
    for key, value in hyperparameters.items() :
        print('Best '+key+':', model.get_params()[key])

# %%
# do the modeling
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=42)
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(random_state=42)

# %% [markdown]
# Bandingkan Hasil

# %%
#predict
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#train
Y_pred_train = model.predict(X_train)
Y_pred_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# Evaluation

# %%
eval_classification(model, Y_pred, X_train, Y_train, X_test, Y_test)
# Out:
# Accuracy (Test Set): 0.51
# Precision (Test Set): 0.53
# Recall (Test Set): 0.00
# F1-Score (Test Set): 0.01
# AUC: 0.50

# %%
print("Precision (Train Set): %.2f" % precision_score(Y_train, Y_pred_train))
# Out:
# Precision (Train Set): 0.52
